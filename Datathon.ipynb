# %% [markdown]
# <a href="https://colab.research.google.com/github/preetanam123/Datathon/blob/main/Datathon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df0 = pd.read_csv("/content/india-districts-census-2011.csv")
df0
# Out:
#      District code                   State name              District name  \
# 0                1            JAMMU AND KASHMIR                    Kupwara
# 1                2            JAMMU AND KASHMIR                     Badgam
# 2                3            JAMMU AND KASHMIR                Leh(Ladakh)
# 3                4            JAMMU AND KASHMIR                     Kargil
# 4                5            JAMMU AND KASHMIR                      Punch
# ..             ...                          ...                        ...
# 635            636                  PONDICHERRY                       Mahe
# 636            637                  PONDICHERRY                   Karaikal
# 637            638  ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 638            639  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 639            640  ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
# ...

# %%
df = df0[['State name', 'District name', 'Population','Households']].copy()
df
# Out:
#                       State name              District name  Population  \
# 0              JAMMU AND KASHMIR                    Kupwara      870354
# 1              JAMMU AND KASHMIR                     Badgam      753745
# 2              JAMMU AND KASHMIR                Leh(Ladakh)      133487
# 3              JAMMU AND KASHMIR                     Kargil      140802
# 4              JAMMU AND KASHMIR                      Punch      476835
# ..                           ...                        ...         ...
# 635                  PONDICHERRY                       Mahe       41816
# 636                  PONDICHERRY                   Karaikal      200222
# 637  ANDAMAN AND NICOBAR ISLANDS                   Nicobars       36842
# 638  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman      105597
# 639  ANDAMAN AND NICOBAR ISLANDS              South Andaman      238142
#
#      Households
# 0        181664
# 1        187839
# 2         54394
# 3         48144
# ...

# %%
df['Ratio'] = df['Population'] / df['Households']
df
# Out:
#                       State name              District name  Population  \
# 0              JAMMU AND KASHMIR                    Kupwara      870354
# 1              JAMMU AND KASHMIR                     Badgam      753745
# 2              JAMMU AND KASHMIR                Leh(Ladakh)      133487
# 3              JAMMU AND KASHMIR                     Kargil      140802
# 4              JAMMU AND KASHMIR                      Punch      476835
# ..                           ...                        ...         ...
# 635                  PONDICHERRY                       Mahe       41816
# 636                  PONDICHERRY                   Karaikal      200222
# 637  ANDAMAN AND NICOBAR ISLANDS                   Nicobars       36842
# 638  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman      105597
# 639  ANDAMAN AND NICOBAR ISLANDS              South Andaman      238142
#
#      Households     Ratio
# 0        181664  4.791010
# 1        187839  4.012718
# ...

# %%
print(np.where(df['Ratio'] >= 4.8))
# Out:
# (array([ 86, 145, 181, 183, 185, 191, 192, 195, 196, 217, 218, 226, 229,
#        230, 231, 233, 234, 235, 236, 237, 238, 239, 260, 271, 272, 346,
#        348, 464, 484]),)

# %%
df1 = df[df['Ratio'] >= 4.8]

# print(df1['District name'].head(5))
df3 = df1.sort_values(by="Ratio", ascending = False)
df2 = df3[['State name', 'District name','Ratio']].copy()
df2.head(5)
# Out:
#     State name District name      Ratio
# 271    MANIPUR      Senapati  12.028619
# 484    GUJARAT         Dohad   5.649571
# 235      BIHAR          Gaya   5.437810
# 230      BIHAR       Bhojpur   5.329680
# 234      BIHAR    Aurangabad   5.321787
